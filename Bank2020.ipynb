# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bank1 = pd.read_excel("BANKS2020.xlsx", sheet_name=1)

# %%
bank1.head()
# Out:
#                   ICICI Bank  \
# 0  Standalone Balance Sheet
# 1                        NaN
# 2   EQUITIES AND LIABILITIES
# 3        SHAREHOLDER'S FUNDS
# 4       Equity Share Capital
#
#                                     Previous Years » Unnamed: 2 Unnamed: 3  \
# 0  ------------------- in Rs. Cr. ---------------...        NaN        NaN
# 1                                             Mar 21       2020       2019
# 2                                                NaN        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4                                            1386.51    1294.76    1294.76
#
#   Unnamed: 4 Unnamed: 5
# 0        NaN        NaN
# 1       2018       2017
# 2        NaN        NaN
# 3        NaN        NaN
# 4    1289.46    1294.14

# %%
#Select data from second row

# %%
bank1 = bank1[1:]

# %%
bank1.head(2)
# Out:
#                  ICICI Bank Previous Years » Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 1                       NaN           Mar 21       2020       2019       2018
# 2  EQUITIES AND LIABILITIES              NaN        NaN        NaN        NaN
#
#   Unnamed: 5
# 1       2017
# 2        NaN

# %%
# Transpose the data

# %%
bank_t = bank1.T

# %%
bank_t.head(2)
# Out:
#                       1                         2                    3   \
# ICICI Bank           NaN  EQUITIES AND LIABILITIES  SHAREHOLDER'S FUNDS
# Previous Years »  Mar 21                       NaN                  NaN
#
#                                     4                    5   \
# ICICI Bank        Equity Share Capital  Total Share Capital
# Previous Years »               1386.51              1386.51
#
#                                    6                     7   \
# ICICI Bank        Revaluation Reserve  Reserves and Surplus
# Previous Years »                    0             146122.67
#
#                                           8                         9   \
# ICICI Bank        Total Reserves and Surplus  Total ShareHolders Funds
# Previous Years »                   146122.67                 147509.18
#
#                          10  ...               81                 82  \
# ICICI Bank         Deposits  ...  Basic EPS (Rs.)  Diluted EPS (Rs.)
# ...

# %%
bank_t.shape
# Out:
# (6, 90)

# %%
# step4: Remove columns with nan
bank_t.dropna(how='all', axis=1, inplace=True)

# %%
bank_t.shape
# Out:
# (6, 81)

# %%
bank_t.head(3)
# Out:
#                       1                         2                    3   \
# ICICI Bank           NaN  EQUITIES AND LIABILITIES  SHAREHOLDER'S FUNDS
# Previous Years »  Mar 21                       NaN                  NaN
# Unnamed: 2          2020                       NaN                  NaN
#
#                                     4                    5   \
# ICICI Bank        Equity Share Capital  Total Share Capital
# Previous Years »               1386.51              1386.51
# Unnamed: 2                     1294.76              1294.76
#
#                                    6                     7   \
# ICICI Bank        Revaluation Reserve  Reserves and Surplus
# Previous Years »                    0             146122.67
# Unnamed: 2                    3114.87             112091.29
#
#                                           8                         9   \
# ICICI Bank        Total Reserves and Surplus  Total ShareHolders Funds
# ...

# %%
bank_t[1][0]
# Out:
# nan

# %%
#Step5 : Convert the first value (nan) in the first columns to Year
bank_t[1][0] = 'Year'

# %%
bank_t[1][0]
# Out:
# 'Year'

# %%
bank_t.head(3)
# Out:
#                       1                         2                    3   \
# ICICI Bank          Year  EQUITIES AND LIABILITIES  SHAREHOLDER'S FUNDS
# Previous Years »  Mar 21                       NaN                  NaN
# Unnamed: 2          2020                       NaN                  NaN
#
#                                     4                    5   \
# ICICI Bank        Equity Share Capital  Total Share Capital
# Previous Years »               1386.51              1386.51
# Unnamed: 2                     1294.76              1294.76
#
#                                    6                     7   \
# ICICI Bank        Revaluation Reserve  Reserves and Surplus
# Previous Years »                    0             146122.67
# Unnamed: 2                    3114.87             112091.29
#
#                                           8                         9   \
# ICICI Bank        Total Reserves and Surplus  Total ShareHolders Funds
# ...

# %%
bank_t.head(3)
# Out:
#                       1                         2                    3   \
# ICICI Bank          Year  EQUITIES AND LIABILITIES  SHAREHOLDER'S FUNDS
# Previous Years »  Mar 21                       NaN                  NaN
# Unnamed: 2          2020                       NaN                  NaN
#
#                                     4                    5   \
# ICICI Bank        Equity Share Capital  Total Share Capital
# Previous Years »               1386.51              1386.51
# Unnamed: 2                     1294.76              1294.76
#
#                                    6                     7   \
# ICICI Bank        Revaluation Reserve  Reserves and Surplus
# Previous Years »                    0             146122.67
# Unnamed: 2                    3114.87             112091.29
#
#                                           8                         9   \
# ICICI Bank        Total Reserves and Surplus  Total ShareHolders Funds
# ...

# %%
bank_t1 = bank_t.copy()

# %% [markdown]
# ### Step7: convert first row into column names

# %%
new_header = bank_t1.iloc[0]
bank_t1 = bank_t1[1:] 
bank_t1.columns = new_header

# %%
bank_t1.head(3)
# Out:
# ICICI Bank          Year EQUITIES AND LIABILITIES SHAREHOLDER'S FUNDS  \
# Previous Years »  Mar 21                      NaN                 NaN
# Unnamed: 2          2020                      NaN                 NaN
# Unnamed: 3          2019                      NaN                 NaN
#
# ICICI Bank       Equity Share Capital Total Share Capital Revaluation Reserve  \
# Previous Years »              1386.51             1386.51                   0
# Unnamed: 2                    1294.76             1294.76             3114.87
# Unnamed: 3                    1294.76             1298.25                   0
#
# ICICI Bank       Reserves and Surplus Total Reserves and Surplus  \
# Previous Years »            146122.67                  146122.67
# Unnamed: 2                  112091.29                  115206.16
# Unnamed: 3                  115206.16                  115206.16
#
# ICICI Bank       Total ShareHolders Funds   Deposits  ... Tax On Dividend  \
# ...

# %%
bank_t1['Symbol'] = bank_t.index[0]

# %%
bank_t.columns
# Out:
# Index([                                                      'Year',
#                                          'EQUITIES AND LIABILITIES',
#                                               'SHAREHOLDER'S FUNDS',
#                                              'Equity Share Capital',
#                                               'Total Share Capital',
#                                               'Revaluation Reserve',
#                                              'Reserves and Surplus',
#                                        'Total Reserves and Surplus',
#                                          'Total ShareHolders Funds',
#                                                          'Deposits',
#                                                        'Borrowings',
#                                  'Other Liabilities and Provisions',
#                                     'Total Capital and Liabilities',
#                                                            'ASSETS',
# ...

# %%
bank_t1.head(5)
# Out:
# ICICI Bank          Year EQUITIES AND LIABILITIES SHAREHOLDER'S FUNDS  \
# Previous Years »  Mar 21                      NaN                 NaN
# Unnamed: 2          2020                      NaN                 NaN
# Unnamed: 3          2019                      NaN                 NaN
# Unnamed: 4          2018                      NaN                 NaN
# Unnamed: 5          2017                      NaN                 NaN
#
# ICICI Bank       Equity Share Capital Total Share Capital Revaluation Reserve  \
# Previous Years »              1386.51             1386.51                   0
# Unnamed: 2                    1294.76             1294.76             3114.87
# Unnamed: 3                    1294.76             1298.25                   0
# Unnamed: 4                    1289.46             1289.46             3044.51
# Unnamed: 5                    1294.14             1294.14                   0
#
# ICICI Bank       Reserves and Surplus Total Reserves and Surplus  \
# ...

# %%
bank_t1.set_index('Symbol', inplace=True)

# %%
bank_t1.head(5)
# Out:
# ICICI Bank    Year EQUITIES AND LIABILITIES SHAREHOLDER'S FUNDS  \
# Symbol
# ICICI Bank  Mar 21                      NaN                 NaN
# ICICI Bank    2020                      NaN                 NaN
# ICICI Bank    2019                      NaN                 NaN
# ICICI Bank    2018                      NaN                 NaN
# ICICI Bank    2017                      NaN                 NaN
#
# ICICI Bank Equity Share Capital Total Share Capital Revaluation Reserve  \
# Symbol
# ICICI Bank              1386.51             1386.51                   0
# ICICI Bank              1294.76             1294.76             3114.87
# ICICI Bank              1294.76             1298.25                   0
# ICICI Bank              1289.46             1289.46             3044.51
# ICICI Bank              1294.14             1294.14                   0
#
# ICICI Bank Reserves and Surplus Total Reserves and Surplus  \
# Symbol
# ...

# %%
bank_t1.dropna(how='all', axis=1, inplace=True)

# %%
bank_t1.head(5)
# Out:
# ICICI Bank    Year Equity Share Capital Total Share Capital  \
# Symbol
# ICICI Bank  Mar 21              1386.51             1386.51
# ICICI Bank    2020              1294.76             1294.76
# ICICI Bank    2019              1294.76             1298.25
# ICICI Bank    2018              1289.46             1289.46
# ICICI Bank    2017              1294.14             1294.14
#
# ICICI Bank Revaluation Reserve Reserves and Surplus  \
# Symbol
# ICICI Bank                   0            146122.67
# ICICI Bank             3114.87            112091.29
# ICICI Bank                   0            115206.16
# ICICI Bank             3044.51             104029.4
# ICICI Bank                   0            107073.91
#
# ICICI Bank Total Reserves and Surplus Total ShareHolders Funds   Deposits  \
# Symbol
# ICICI Bank                  146122.67                147509.18  932522.16
# ICICI Bank                  115206.16                116504.41  770968.99
# ...

# %%
bank_t1.dropna(how='all', axis=0, inplace=True)

# %%
bank_t1.head(5)
# Out:
# ICICI Bank    Year Equity Share Capital Total Share Capital  \
# Symbol
# ICICI Bank  Mar 21              1386.51             1386.51
# ICICI Bank    2020              1294.76             1294.76
# ICICI Bank    2019              1294.76             1298.25
# ICICI Bank    2018              1289.46             1289.46
# ICICI Bank    2017              1294.14             1294.14
#
# ICICI Bank Revaluation Reserve Reserves and Surplus  \
# Symbol
# ICICI Bank                   0            146122.67
# ICICI Bank             3114.87            112091.29
# ICICI Bank                   0            115206.16
# ICICI Bank             3044.51             104029.4
# ICICI Bank                   0            107073.91
#
# ICICI Bank Total Reserves and Surplus Total ShareHolders Funds   Deposits  \
# Symbol
# ICICI Bank                  146122.67                147509.18  932522.16
# ICICI Bank                  115206.16                116504.41  770968.99
# ...

# %% [markdown]
# # Sheet 2

# %%
bank2 = pd.read_excel("BANKS2020.xlsx", sheet_name=2)

# %%
bank2 = bank2[1:]

# %%
bank_t = bank2.T

# %%
bank_t.dropna(how='all', axis=1, inplace=True)

# %%
bank_t
# Out:
#                       1                         2                    3   \
# HDFC Bank            NaN  EQUITIES AND LIABILITIES  SHAREHOLDER'S FUNDS
# Previous Years »  Mar 20                       NaN                  NaN
# Unnamed: 2          2020                       NaN                  NaN
# Unnamed: 3          2019                       NaN                  NaN
# Unnamed: 4          2018                       NaN                  NaN
# Unnamed: 5          2017                       NaN                  NaN
#
#                                     4                    5   \
# HDFC Bank         Equity Share Capital  Total Share Capital
# Previous Years »                548.33               548.33
# Unnamed: 2                      548.33               548.33
# Unnamed: 3                      544.66               544.66
# Unnamed: 4                      544.66               544.66
# Unnamed: 5                      519.02               519.02
#
# ...

# %%
bank_t[1][0] = 'Year'

# %%
bank_t.head()
# Out:
#                       1                         2                    3   \
# HDFC Bank           Year  EQUITIES AND LIABILITIES  SHAREHOLDER'S FUNDS
# Previous Years »  Mar 20                       NaN                  NaN
# Unnamed: 2          2020                       NaN                  NaN
# Unnamed: 3          2019                       NaN                  NaN
# Unnamed: 4          2018                       NaN                  NaN
#
#                                     4                    5   \
# HDFC Bank         Equity Share Capital  Total Share Capital
# Previous Years »                548.33               548.33
# Unnamed: 2                      548.33               548.33
# Unnamed: 3                      544.66               544.66
# Unnamed: 4                      544.66               544.66
#
#                                     7                           8   \
# HDFC Bank         Reserves and Surplus  Total Reserves and Surplus
# ...

# %%
bank_t2 = bank_t.copy()

# %%
bank_t2.columns = bank_t2.iloc[0]

# %%
bank_t2 = bank_t2[1:]

# %%
bank_t2['Symbol'] = bank_t.index[0]

# %%
bank_t2.set_index('Symbol', inplace=True)

# %%
bank_t2.head(5)
# Out:
# HDFC Bank    Year EQUITIES AND LIABILITIES SHAREHOLDER'S FUNDS  \
# Symbol
# HDFC Bank  Mar 20                      NaN                 NaN
# HDFC Bank    2020                      NaN                 NaN
# HDFC Bank    2019                      NaN                 NaN
# HDFC Bank    2018                      NaN                 NaN
# HDFC Bank    2017                      NaN                 NaN
#
# HDFC Bank Equity Share Capital Total Share Capital Reserves and Surplus  \
# Symbol
# HDFC Bank               548.33              548.33             170437.7
# HDFC Bank               548.33              548.33            170437.69
# HDFC Bank               544.66              544.66            148661.69
# HDFC Bank               544.66              544.66            148661.66
# HDFC Bank               519.02              519.02            105775.98
#
# HDFC Bank Total Reserves and Surplus Total ShareHolders Funds    Deposits  \
# Symbol
# ...

# %%
bank_all = pd.concat([bank])

# %%
bank = pd.DataFrame()

for i in np.arange(1,28):
    df = pd.read_excel('BANKS2020.xlsx', sheet_name=i)
    df = df[1:]
    df = df.T
    df.dropna(how='all', axis=1, inplace=True)
    df.dropna(how='all', axis=0, inplace=True)
    df[1][0] = 'Year'
    df1 = df.copy()
    df1.columns = df1.iloc[0]
    df1 = df1[1:]
    df1['Symbol'] = df.index[0]
    df1.set_index('Symbol', inplace=True)
    df1.dropna(how='all', axis=1, inplace=True)
    df1.dropna(how='all', axis=0, inplace=True)
    df1 = df1.loc[:,df1.columns.notnull()]
    bank = pd.concat([bank, df1])

# %%
bank
# Out:
#                        Year Equity Share Capital Total Share Capital  \
# Symbol
# ICICI Bank           Mar 21              1386.51             1386.51
# ICICI Bank             2020              1294.76             1294.76
# ICICI Bank             2019              1294.76             1298.25
# ICICI Bank             2018              1289.46             1289.46
# ICICI Bank             2017              1294.14             1294.14
# ...                     ...                  ...                 ...
# Union Bank of India  2017.0              1168.57             1168.57
# Bank Of Baroda       2020.0               925.37              925.37
# Bank Of Baroda       2019.0               530.36              530.36
# Bank Of Baroda       2018.0               530.36              530.36
# Bank Of Baroda       2017.0               462.09              462.09
#
#                     Revaluation Reserve Reserves and Surplus  \
# Symbol
# ...
